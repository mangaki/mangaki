# %%
from mangaki.utils.anidb import AniDB

a = AniDB('mangakihttp', 1)
a.get(8069)
# Out:
# <anime id="8069" restricted="false">
# <type>TV Series</type>
# <episodecount>12</episodecount>
# <startdate>2011-01-07</startdate>
# <enddate>2011-04-22</enddate>
# <titles>
# <title type="main" xml:lang="x-jat">Mahou Shoujo Madoka Magica</title>
# <title type="synonym" xml:lang="en">Magical Girl Madoka Magika</title>
# <title type="synonym" xml:lang="ru">Волшебница Мадока Магика</title>
# <title type="synonym" xml:lang="x-jat">Mahou Shoujo Madoka Magika</title>
# <title type="synonym" xml:lang="x-jat">Meduka Meguca</title>
# <title type="synonym" xml:lang="uk">Чарівниця Мадока Магіка</title>
# <title type="synonym" xml:lang="uk">Дівчина-чарівниця Мадока Маґіка</title>
# <title type="synonym" xml:lang="fa">مدوکا مجیکا دختر جادویی</title>
# <title type="short" xml:lang="ja">まどマギ</title>
# <title type="short" xml:lang="ja">マドマギ</title>
# <title type="short" xml:lang="en">PMMM</title>
# <title type="short" xml:lang="en">pmagi</title>
# <title type="short" xml:lang="en">MSMM</title>
# ...
